# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyDtdAeDZH3h-SFl6IgJP1S5hHDSTemg1BA")
model = genai.GenerativeModel('gemini-2.5-flash-lite')

# Start a chat session with history memory
chat = model.start_chat(history=[])

while True:
    user_input = input("You: ")
    response = chat.send_message(user_input)
    print(f"Bot: {response.text}")
# Out:
# Bot: Hello! How can I help you today?
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 11
#       9 while True:
#      10     user_input = input("You: ")
# ---> 11     response = chat.send_message(user_input)
#      12     print(f"Bot: {response.text}")
#
# File c:\Users\Acer-Swift\anaconda3\Lib\site-packages\google\generativeai\generative_models.py:564, in ChatSession.send_message(self, content, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     558     raise NotImplementedError(
#     559         "Unsupported configuration: The `google.generativeai` SDK currently does not support the combination of `stream=True` and `enable_automatic_function_calling=True`."
#     560     )
#     562 tools_lib = self.model._get_tools_lib(tools)
# --> 564 content = content_types.to_content(content)
#     566 if not content.role:
#     567     content.role = _USER_ROLE
#
# File c:\Users\Acer-Swift\anaconda3\Lib\site-packages\google\generativeai\types\content_types.py:286, in to_content(content)
#     284 def to_content(content: ContentType):
#     285     if not content:
# --> 286         raise ValueError(
#     287             "Invalid input: 'content' argument must not be empty. Please provide a non-empty value."
#     288         )
#     290     if isinstance(content, Mapping):
#     291         content = _convert_dict(content)
#
# ValueError: Invalid input: 'content' argument must not be empty. Please provide a non-empty value.
